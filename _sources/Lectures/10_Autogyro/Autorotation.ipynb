# %% [markdown]
# # Autorotation

# %% [markdown]
# - Fundamental to every helicopter design
#     - prevents it from "falling like a rock" in case of mishap

# %% [markdown]
# <div style="float:right; width:43%;" >
#     <img src="../../assets/B0_fig4_4.png" class="big" />
#     <p style="text-align:center; color:gray; font-size:16px;"> ...  </p>
# </div>

# %% [markdown]
# ## Alternate safety procedures

# %% [markdown]
# Seats on the early versions of F-104 Starfighter jets were made so that they ejected downwards because the high tail design of the jet, along with lack of powerful rockets on ejection seats, made it difficult for the pilot to steer clear of the plane in time.
#
# <center>
#     <img src="../../assets/F104_ejection.webp" class="medium">
#     <p style="font-size:16px; color:gray; text-align:center;" > Downward ejection on a F-104 Starfighter <a href="https://www.bbc.com/future/article/20220802-why-some-aircraft-had-downward-firing-ejector-seats"> [source]</a></p>
#
# </center>

# %% [markdown]
# Among helicopters, only the Kamov Ka-50 and Ka-52 attack helicopters are known to exhibit escape systems resembling resembling their fixed-wing counterparts. The effectiveness and reliability of a such a system, made separately by every helicopter manufacturer, has led them to the conclusion that it isn't worth it.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('H9Qt5CCVqP8', width=700, height=300)
