# %% [markdown]
# # Advancing Blade Concept (ABC)

# %% [markdown]
# <center>
#     <img src="../../assets/ABC2.png" class="medium">
#     <p style="font-size:12px; color:gray; text-align:center;"  > Lateral loading symmetry on ABC rotor  <a href="https://www.sikorskyarchives.com/S-69%20(XH-59A).php"> [source]</a></p>
#
# </center>

# %% [markdown]
# The XH-59 from Sikorsky was the first design incorporating this design philosophy
# - no blade hinges
# - no tail rotor - yaw control?
#     - differential collective for yaw control in hover/low speed
#     - gearbox designed with differential speed capability!!
#     - vertical tail in fast
# - coaxial design makes controls more complicated
# - overall design more compact
#     - largest dimension is often the rotor radius (show pics)
#     -

# %% [markdown]
# read P152

# %% [markdown]
# The version without thrust compounding achieved 296 km/hr and the one with turbojets installed achieved 488 km/hr {cite}`Add48`.

# %% [markdown]
# <center>
#     <img src="../../assets/XH59Ad.png" class="medium">
#     <p style="font-size:12px; color:gray; text-align:center;"  > Sikorsky XH-59 <a href="https://www.sikorskyarchives.com/S-69%20(XH-59A).php"> [source]</a></p>
#
# </center>

# %% [markdown]
# ```{epigraph}
# "Being a concept demonstrator, the XH-59A had a number of compromises in its design to hold program cost down.  Primarily among these was the use of separate engines for rotor power and auxiliary propulsion.  In a more developed design, a single propulsion system would power both the rotor and an auxiliary propulsion propeller or ducted fan.  A high cost item at the time was the monolithic titanium blade spars.  Composite materials technology would soon appear which could produce a better blade, with almost infinite options in geometry, at a substantially reduced cost and lighter weight.
#
# Rotor vibration characteristics were acknowledged at the end of the test program as being too high for a production vehicle.  Design studies showed that four-bladed rotors would dramatically reduce the rotors’ vibratory characteristics. "
#
# -- [Sikorsky Archives](https://www.sikorskyarchives.com/S-69%20(XH-59A).php)
# ```

# %% [markdown]
# ```{admonition} Aside
# Strangely, Sikorsky were a bit more upbeat during the development and testing phase writing - "...It has been determined that with no vibration treatment installed (absorbers or isolators) the vibration levels are the same magnitude as untreated current generation helicopters..." at the [36th AHS Annual Forum] (https://vtol.org/store/product/advancing-blade-concepts-abc-tm-high-speed-development-2257.cfm)
# ```

# %% [markdown]
# <center>
#     <img src="../../assets/P152_4.png" class="medium">
#     <p class="caption"> Schematic of lift variation over a single rotor disk in forward flight <a href="https://vtol.org/store/product/the-abc-rotor-a-historical-perspective-4111.cfm"> [source] </a></p>
# </center>

# %% [markdown]
# The limitations in thrust-producing abilities of the rotor on the retreating sides, due to low dynamic pressure, are a significant impediment to exploiting the full aerodynamic lifting characteristics of the blades. This is apparent from the figure above.

# %% [markdown]
# <center>
#     <img src="../../assets/P152_1_1.png" class="medium">
#     <p class="caption"> Schematic of thrust generated by coaxial rotor in forward flight <a href="https://vtol.org/store/product/the-abc-rotor-a-historical-perspective-4111.cfm">[source] </a></p>
# </center>

# %% [markdown]
# ## Physical attributes

# %% [markdown]
# - rotors are rigidly attached to the hub (no hinges or flexbeams!)
#     -
# -

# %% [markdown]
# ```{toggle}
# The advancing blade tips would start experiencing high drag as Mach divergence number (~0.9) is achieved. So to fully exploit the advantages of ABC, the rotors need to be slowed down. In the original ABC concept demonstrator (XH-49A) the tip speed was reduced from 198 m/s to 137 m/s
# ```

# %% [markdown]
# ## Sikorsky XH-49A

# %% [markdown]
# Coaxial rotors
# Thrust-compounding with turbojets

# %% [markdown]
# ## How it started

# %% [markdown]
# <div class="image-grid">
#     <img  src="../../assets/P152_1.png" class="big"/>
#     <img  src="../../assets/P152_2.png" class="big"/>
#     <img  src="../../assets/P152_3.png" class="big" />
#
#
# </div>
#
# <div class="image-grid">
#   <p style="font-size:55%; color:gray; text-align:left;"> ABC demonstrator <a href="https://vtol.org/store/product/the-abc-rotor-a-historical-perspective-4111.cfm"> [source]</a></p>
#   <p style="font-size:55%; color:gray; text-align:left;"> ABC concept aircraft <a href="https://vtol.org/store/product/the-abc-rotor-a-historical-perspective-4111.cfm"> [source]</a></p>
#   <p style="font-size:55%; color:gray; text-align:left;"> ABC concept armoured aircraft <a href="https://vtol.org/store/product/the-abc-rotor-a-historical-perspective-4111.cfm"> [source]</a></p>
# </div>

# %% [markdown]
# ## How it is going

# %% [markdown]
# <div class="image-grid">
#     <img  src="../../assets/X2.jpeg" class="big"/>
#     <img  src="../../assets/Raider.jpeg" class="big"/>
#     <img  src="../../assets/Defiant.jpg" class="big" />
#
#
# </div>
#
# <div class="image-grid">
#   <p style="font-size:55%; color:gray; text-align:left;"> X2 <a href="https://www.wired.com/2010/08/sikorsky-x2-breaks-helicopter-speed-record/"> [source]</a></p>
#   <p style="font-size:55%; color:gray; text-align:left;"> ABC concept aircraft <a href="https://en.wikipedia.org/wiki/Sikorsky_S-97_Raider#/media/File:Sikorsky_S-97_Raider_in_flight.jpg"> [source]</a></p>
#   <p style="font-size:55%; color:gray; text-align:left;"> ABC concept armoured aircraft <a href="https://en.wikipedia.org/wiki/Sikorsky%E2%80%93Boeing_SB-1_Defiant#/media/File:Sikorsky%E2%80%93Boeing_SB-1_Defiant_(cropped).jpg"> [source]</a></p>
# </div>

# %% [markdown]
# X2 set a speed record of 468 km/hr {cite}`Add48`.

# %% [markdown]
# ## Advantages

# %% [markdown]
# - permits large variation in helicopter CG

# %% [markdown]
# - (B28) retreating side doesn't need to operate at high CL anymore so stall can be avoided there

# %% [markdown]
# ## So, are all future helicopters going to be ABC designs?
